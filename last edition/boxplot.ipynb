# %% [markdown]
# # project of gender_classification

# %% [markdown]
# ##### import

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ##### read the dataset

# %%
dataset1 = pd.read_csv("gender_classification_v7.csv")
dataset1
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %%
plt.pie(dataset1['gender'].value_counts() , autopct = '%.2f%%')
plt.legend(['male', 'female'])
plt.show()

# %% [markdown]
# ##### columns

# %%
dataset1.columns
# Out:
# Index(['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide',
#        'nose_long', 'lips_thin', 'distance_nose_to_lip_long', 'gender'],
#       dtype='object')

# %% [markdown]
# ## boxplot

# %%
dataset1.boxplot(figsize=(15, 5))
# Out:
# <Axes: >

# %%
fig = plt.figure(figsize =(12, 7))
plt.subplot(2,3,1)
plt.boxplot(dataset1["long_hair"])
plt.title("long_hair")
plt.subplot(2,3,2)
plt.boxplot(dataset1["forehead_width_cm"])
plt.title("forehead_width_cm")
plt.subplot(2,3,3)
plt.boxplot(dataset1["forehead_height_cm"])
plt.title("forehead_height_cm")
plt.subplot(2,3,4)
plt.boxplot(dataset1["nose_wide"])
plt.title("nose_wide")
plt.subplot(2,3,5)
plt.boxplot(dataset1["nose_long"])
plt.title("nose_long")
plt.subplot(2,3,6)
plt.boxplot(dataset1["lips_thin"])
plt.title("lips_thin")
plt.show()

# %%
for feature in dataset1.columns[:-1]:
    sns.boxplot(dataset1, y=f"{feature}" , hue="gender")
    plt.show()
