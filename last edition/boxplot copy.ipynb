# %% [markdown]
# # project of gender_classification

# %% [markdown]
# ##### import

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ##### read the dataset

# %%
dataset1 = pd.read_csv("gender_classification_v7.csv")
dataset1
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %% [markdown]
# ##### columns

# %%
dataset1.columns
# Out:
# Index(['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide',
#        'nose_long', 'lips_thin', 'distance_nose_to_lip_long', 'gender'],
#       dtype='object')

# %% [markdown]
# ## merge the feture

# %%
dataset1['nose_w_l'] = dataset1['nose_wide'] ^ dataset1['nose_long']
dataset1
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %%
print(dataset1.columns[0])
# Out:
# long_hair

# %%
# فرض کنید df دیتافریم شما باشد
cols = dataset1.columns.tolist()

# جابه‌جا کردن ستون‌ها
cols[3], cols[8] = cols[8], cols[3]

dataset1 = dataset1[cols]
dataset1
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_w_l  nose_long  \
# 0             1               11.8                 6.1         1          0
# 1             0               14.0                 5.4         0          0
# 2             0               11.8                 6.3         0          1
# 3             0               14.4                 6.1         1          1
# 4             1               13.5                 5.9         0          0
# ...         ...                ...                 ...       ...        ...
# 4996          1               13.6                 5.1         0          0
# 4997          1               11.9                 5.4         0          0
# 4998          1               12.9                 5.7         0          0
# 4999          1               13.2                 6.2         0          0
# 5000          1               15.4                 5.4         0          1
#
# ...

# %%
dataset1.drop("nose_long",inplace=True ,axis=1)
dataset1.drop("nose_wide",inplace=True ,axis=1)
dataset1
# Out:
# C:\Users\SH EG\AppData\Local\Temp\ipykernel_5784\348454992.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset1.drop("nose_long",inplace=True ,axis=1)
# C:\Users\SH EG\AppData\Local\Temp\ipykernel_5784\348454992.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset1.drop("nose_wide",inplace=True ,axis=1)
#       long_hair  forehead_width_cm  forehead_height_cm  nose_w_l  lips_thin  \
# 0             1               11.8                 6.1         1          1
# 1             0               14.0                 5.4         0          1
# ...

# %% [markdown]
# ## boxplot

# %%
dataset1.boxplot(figsize=(15, 5))
# Out:
# <Axes: >

# %%
fig = plt.figure(figsize =(12, 7))
plt.subplot(2,3,1)
plt.boxplot(dataset1["long_hair"])
plt.title("long_hair")
plt.subplot(2,3,2)
plt.boxplot(dataset1["forehead_width_cm"])
plt.title("forehead_width_cm")
plt.subplot(2,3,3)
plt.boxplot(dataset1["forehead_height_cm"])
plt.title("forehead_height_cm")
plt.subplot(2,3,4)
plt.boxplot(dataset1["nose_w_l"])
plt.title("nose_w_l")
plt.subplot(2,3,5)
plt.boxplot(dataset1["lips_thin"])
plt.title("lips_thin")
plt.subplot(2,3,6)
plt.boxplot(dataset1["distance_nose_to_lip_long"])
plt.title("distance_nose_to_lip_long")
plt.show()
